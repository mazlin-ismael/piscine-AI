# %%
import pandas as pd
import numpy as np

# %%
business_dates = pd.bdate_range('2021-01-01', '2021-12-31')

#generate tickers
tickers = ['AAPL', 'FB', 'GE', 'AMZN', 'DAI']

#create indexs
index = pd.MultiIndex.from_product([business_dates, tickers], names=['Date', 'Ticker'])

# create DFs
market_data = pd.DataFrame(index=index,
                        data=np.random.randn(len(index), 1),
                        columns=['Prediction'])
market_data
# Out:
#                    Prediction
# Date       Ticker
# 2021-01-01 AAPL     -0.515809
#            FB        0.031386
#            GE       -1.202139
#            AMZN     -0.619145
#            DAI       0.075798
# ...                       ...
# 2021-12-31 AAPL     -1.404564
#            FB       -0.135132
#            GE        0.444454
#            AMZN      1.853707
#            DAI      -0.565067
#
# [1305 rows x 1 columns]

# %%
unstacked_df = market_data.unstack()
unstacked_df.head().index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-04', '2021-01-05', '2021-01-06',
#                '2021-01-07'],
#               dtype='datetime64[ns]', name='Date', freq='B')

# %%
unstacked_df.plot(y="Prediction", use_index=True, title="Tickers Predictions YEAR 2021")
# unstacked.plot(title = 'Stocks 2021'
# Out:
# <Axes: title={'center': 'Tickers Predictions YEAR 2021'}, xlabel='Date'>
